# %% [markdown]
# ## Download and Preprocess Databases

# %% [markdown]
# ###### Note this can take a few hours but only needs to be done once a year approximately

# %%
from cpiextract.utils.prepare_cpiextract_data import (prepare_pubchem, prepare_chembl, prepare_otp,
    prepare_bindingdb, prepare_ctd, prepare_drugbank,prepare_stitch, prepare_dtc, prepare_drugcentral)

# %%
data_path='/path/to/data/CPE_data/'  # Data Storage path

# %% [markdown]
# #### Automated through website APIs

# %%
prepare_pubchem(data_path)
# Out:
# === PubChem ===
#   [skip] pubchem.duckdb already present

# %%
prepare_otp(data_path,otp_version='latest')
# Out:
# === Open Targets Platform (OTP) ===
#   Using explicitly-requested OTP version: latest
#   Listing parquet files at http://ftp.ebi.ac.uk/pub/databases/opentargets/platform/latest/output/drug_mechanism_of_action/
#   Found 2 parquet files
# ...
#   [skip] part-00000-10b94b1b-f29a-440c-98e0-c91862b6d2a8-c000.snappy.parquet already present
#   [skip] part-00001-10b94b1b-f29a-440c-98e0-c91862b6d2a8-c000.snappy.parquet already present
#   Retrieved 13005 rows
#   After exploding chemblIds/targets: 30767 rows
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] SID-Map.gz already present
# Parsing SID-Map.gz: 100%|██████████| 3.34G/3.34G [04:24<00:00, 13.6MB/s]
#   Matched 4,374,050 rows across the 5 relevant sources - building DataFrame...
#   Writing pubchem-source-SIDs.csv...
#   Built pubchem-source-SIDs.csv: 4,374,050 rows
#   [skip] CID-InChI-Key.gz already present
# ...

# %%
prepare_chembl(data_path)
# Out:
# === ChEMBL ===
#   Latest ChEMBL release found: chembl_37_sqlite.tar.gz
#   [skip] chembl_37_sqlite.tar.gz already present
#   Extracting...
#   Running extraction query...
#   Retrieved 6178939 compound-protein interactions
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
#   [skip] pubchem-cid-inchikey.csv already present
#     6178939 interactions -> 6178845 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/ChEMBL_standardized.csv

# %% [markdown]
# #### Manually downloaded databases

# %% [markdown]
# ###### Checks for raw files and prints instructions if missing

# %%
prepare_bindingdb(data_path)
# Out:
# === BindingDB ===
#   Extracting BindingDB_All_202609_tsv.zip...
#   Loading (this is a large file, can take a while)...
#   Retrieved 3237047 compound-protein interactions
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
#   [skip] pubchem-cid-inchikey.csv already present
#     3237047 interactions -> 3228529 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/BindingDB_standardized.csv

# %%
prepare_ctd(data_path)
# Out:
# === CTD ===
#   Retrieved 3158204 compound-protein interactions
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
#   [skip] pubchem-cid-inchikey.csv already present
#     3158204 interactions -> 1681915 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/CTD_standardized.csv

# %%
prepare_drugbank(data_path)
# Out:
# === DrugBank ===
#   Extracting drugbank_all_full_database.xml.zip...
#   Parsing XML (this can take several minutes for the full database)...
#   Extracted 37287 drug-protein relationships
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
#   [skip] pubchem-cid-inchikey.csv already present
#     37287 interactions -> 34077 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/DrugBank_standardized.csv

# %%
prepare_dtc(data_path)
# Out:
# === DTC (DrugTargetCommons) ===
#   Retrieved 5846730 compound-protein interactions
#   Standardizing (linking to PubChem CID/InChIKey via ChEMBL compound_id)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
# Reading pubchem-source-SIDs.csv:   0%|          | 0.00/195M [00:04<?, ?B/s]
#   [skip] pubchem-cid-inchikey.csv already present
# Reading pubchem-cid-inchikey.csv:   0%|          | 0.00/5.41G [02:37<?, ?B/s]
#     5846730 interactions -> 5816941 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/DTC_standardized.csv

# %%
prepare_drugcentral(data_path)
# Out:
# === DrugCentral ===
#   Retrieved 19378 compound-protein interactions
#   Standardizing (linking to PubChem CID/InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
# Reading pubchem-source-SIDs.csv:   0%|          | 0.00/195M [00:04<?, ?B/s]
#   [skip] pubchem-cid-inchikey.csv already present
# Reading pubchem-cid-inchikey.csv:   0%|          | 0.00/5.41G [02:36<?, ?B/s]
#     19378 interactions -> 18856 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/DrugCentral_standardized.csv

# %%
prepare_stitch(data_path)
# Out:
# === STITCH ===
#   Retrieved 15473939 compound-protein interactions
#   Standardizing (linking to PubChem InChIKey)...
# Building PubChem reference tables (Source/CID/InChIKey mappings)...
#   [skip] pubchem-source-SIDs.csv already present
# Reading pubchem-source-SIDs.csv:   0%|          | 0.00/195M [00:04<?, ?B/s]
#   [skip] pubchem-cid-inchikey.csv already present
# Reading pubchem-cid-inchikey.csv:   0%|          | 0.00/5.41G [02:34<?, ?B/s]
#     15473939 interactions -> 14974461 with a PubChem CID and inchikey match
#   Saved /projects/ccnr/sebek.m/CPE_data/STITCH_standardized.csv
